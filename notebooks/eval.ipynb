# %% [markdown]
# # Notebook for testing answers evaluation

# %% [markdown]
# ## Init

# %%
from query_ai import QueryAI

llm = QueryAI()

# %% [markdown]
# ## Set prompt

# %%
SYSTEM_PROMPT = """
You are an expert Java evaluator. Score the candidate's answer from 1 to 5.
Rubric:
5 = Completely correct, precise, and clear.
4 = Mostly correct, minor omission.
3 = Partially correct, but missing important details.
2 = Mostly incorrect, small parts may be true.
1 = Completely incorrect or irrelevant.
"""

# %%
PROMPT = """
question: What are the four main principles of Object-Oriented Programming?
answer: They are: abstraction, encapsulation, inheritance, polymorphism
"""

# %%
messages = [
    {"role": "system", "content": SYSTEM_PROMPT},
    {"role": "user", "content": PROMPT}
]

# %%
response = llm.query_ai(messages)
# Out:
# 1
# ...

# %%
print(response)
# Out:
# ("Score: 5\n\nThe candidate's answer is completely correct, precise, and clear. They accurately identified the four main principles of Object-Oriented Programming: abstraction, encapsulation, inheritance, and polymorphism.", 'chatcmpl-ClFLgrVoAKlfZZJ0pt5WGwOccF3qy')
